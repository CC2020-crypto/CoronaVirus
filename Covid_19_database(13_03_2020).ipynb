# %% [markdown]
# <a href="https://colab.research.google.com/github/CC2020-crypto/CoronaVirus/blob/master/Covid_19_database(13_03_2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
dataset = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/DataSets/covid_19_data.csv', delimiter = ',')

# %%
dataset
# Out:
#     Province/State Country/Region  Latitude  ...  Confirmed Deaths  Recovered
# 0            Hubei          China   30.9756  ...      67786   3062      51553
# 1        Guangdong          China   23.3417  ...       1356      8       1296
# 2            Henan          China   33.8820  ...       1273     22       1249
# 3         Zhejiang          China   29.1832  ...       1215      1       1197
# 4            Hunan          China   27.6104  ...       1018      4       1005
# ..             ...            ...       ...  ...        ...    ...        ...
# 225            NaN    Afghanistan   33.0000  ...          7      0          0
# 226            NaN         Monaco   43.7333  ...          2      0          0
# 227            NaN  Liechtenstein   47.1400  ...          1      0          0
# 228            NaN         Guyana    5.0000  ...          1      1          0
# 229            NaN         Taiwan   23.7000  ...         50      1         20
#
# [230 rows x 8 columns]

# %%
dataset_clean = dataset.drop(['Latitude', 'Longitude'],axis=1)
dataset_clean.rename({'Province/State':'Province','Country/Region':'Country'},axis=1,inplace=True)
dataset_clean
# Out:
#       Province        Country     Last  Update  Confirmed  Deaths  Recovered
# 0        Hubei          China  3/13/2020 11:09      67786    3062      51553
# 1    Guangdong          China  3/13/2020 11:09       1356       8       1296
# 2        Henan          China   3/11/2020 8:13       1273      22       1249
# 3     Zhejiang          China   3/12/2020 1:33       1215       1       1197
# 4        Hunan          China  3/13/2020 11:09       1018       4       1005
# ..         ...            ...              ...        ...     ...        ...
# 225        NaN    Afghanistan  3/11/2020 20:00          7       0          0
# 226        NaN         Monaco  3/11/2020 20:00          2       0          0
# 227        NaN  Liechtenstein  3/11/2020 20:00          1       0          0
# 228        NaN         Guyana  3/11/2020 20:00          1       1          0
# 229        NaN         Taiwan  3/11/2020 20:00         50       1         20
#
# [230 rows x 6 columns]

# %%
dataset_clean.describe(include='all')
# Out:
#               Province Country  ...       Deaths    Recovered
# count              113     230  ...   230.000000    230.00000
# unique             111     125  ...          NaN          NaN
# top     Grand Princess      US  ...          NaN          NaN
# freq                 2      53  ...          NaN          NaN
# mean               NaN     NaN  ...    23.495652    305.43913
# std                NaN     NaN  ...   220.633482   3406.53904
# min                NaN     NaN  ...     0.000000      0.00000
# 25%                NaN     NaN  ...     0.000000      0.00000
# 50%                NaN     NaN  ...     0.000000      0.00000
# 75%                NaN     NaN  ...     1.000000      4.75000
# max                NaN     NaN  ...  3062.000000  51553.00000
#
# [11 rows x 6 columns]

# %%
dataset_clean
# Out:
#       Province        Country     Last  Update  Confirmed  Deaths  Recovered
# 0        Hubei          China  3/13/2020 11:09      67786    3062      51553
# 1    Guangdong          China  3/13/2020 11:09       1356       8       1296
# 2        Henan          China   3/11/2020 8:13       1273      22       1249
# 3     Zhejiang          China   3/12/2020 1:33       1215       1       1197
# 4        Hunan          China  3/13/2020 11:09       1018       4       1005
# ..         ...            ...              ...        ...     ...        ...
# 225        NaN    Afghanistan  3/11/2020 20:00          7       0          0
# 226        NaN         Monaco  3/11/2020 20:00          2       0          0
# 227        NaN  Liechtenstein  3/11/2020 20:00          1       0          0
# 228        NaN         Guyana  3/11/2020 20:00          1       1          0
# 229        NaN         Taiwan  3/11/2020 20:00         50       1         20
#
# [230 rows x 6 columns]

# %%
dataset_clean['Confirmed'].value_counts().sort_values()
# Out:
# 760      1
# 41       1
# 1139     1
# 112      1
# 804      1
#         ..
# 3        6
# 13       6
# 5        9
# 2       15
# 1       30
# Name: Confirmed, Length: 117, dtype: int64

# %%
dataset_clean[:10].plot.bar(x='Country',y=['Confirmed','Deaths','Recovered'])
